# %% [markdown]
# ${\bf Problema}$ ${\bf 1:}$ Resolva os seguintes problemas usando o método de Euler com passos h = 0.2,0.1,0.05. Compute o erro relativo usando a solução exata ${y(t).}$ Para valores selecionados de ${t,}$ observe a razão com o que o erro diminui á medida que ${h}$ é reduzido pela metade.
#
# ${a)}$ ${y'(t) = [cos(y(t))],^{2}}$ ${0}$ ${\leq}$ ${t}$ ${\leq}$ ${10,}$ ${y(0) = 0;}$ ${y(t) = tan^{-1}(t)}$
#
# ${\bf Limite}$ ${\bf do}$ ${\bf erro:}$
#
# ${\dfrac {\partial [cos(y(t))^{2}]}{\partial y}}$ ${=}$ ${-2tcos(yt)sen(yt)}$
#
# E como ${y'(t) = tan^{-1}(t)}$
# ${y(t)}$ ${=}$ ${\dfrac {1}{t^{2} + 1,}}$ logo ${L = {\dfrac {1}{t^{2} + 1}}}$
#
# ${|y(t)|}$ ${\leq}$ ${\dfrac {1}{t^{2} - 1}}$ para todo ${t}$ pertencente a ${0}$ ${\leq}$ ${t}$ ${\leq}$ ${10}$

# %%
#----------- h = 0.2 --------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])

    return (t,y)

def f(t,y):
    return (cos(y))**2

# solucao numerica
t,y = euler_expl (0, 10, 0, 0.2, f)
            
# solucao exata
yex = np.tan(y)**-1

# erro
erro = np.abs (y - yex)
plt.plot (erro, 'g', label = '$Erro Rel$')
plt.legend()

# limite de integração
#lim_erro = 0.1*(0.5*np.exp(1)**2-2)*(np.exp(t)-1.)

#tabela
print ("Imprimindo comparação... \n\n ti |    ei   | Ei   \n")
for i in range(len(y)):
    print("{0:.1f} | {1: 0.5f} | {2: 0.5f} \n".format (t[i], erro[i], lim_erro[i]))
# Out:
# C:\Users\anaca\Anaconda3\envs\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: divide by zero encountered in reciprocal
# Imprimindo comparação...
#
#  ti |    ei   | Ei
#
# 0.0 |  inf |  0.00000
#
# 0.2 |  4.73315 |  0.01782
#
# 0.4 |  2.02616 |  0.03752
#
# 0.6 |  1.02189 |  0.05928
#
# 0.8 |  0.46707 |  0.08334
#
# 1.0 |  0.10801 |  0.10993
#
# 1.2 |  0.14432 |  0.13931
#
# 1.4 |  0.33118 |  0.17178
#
# 1.6 |  0.47491 |  0.20767
#
# 1.8 |  0.58876 |  0.24733
#
# 2.0 |  0.68109 |  0.29117
#
# 2.2 |  0.75745 |  0.33961
#
# 2.4 |  0.82163 |  0.39315
#
# 2.6 |  0.87633 |  0.45232
#
# 2.8 |  0.92351 |  0.51771
#
# 3.0 |  0.96461 |  0.58998
#
# 3.2 |  1.00074 |  0.66985
#
# 3.4 |  1.03276 |  0.75812
#
# 3.6 |  1.06133 |  0.85568
#
# 3.8 |  1.08698 |  0.96349
#
# 4.0 |  1.11014 |  1.08264
#
# 4.2 |  1.13116 |  1.21433
#
# 4.4 |  1.15032 |  1.35986
#
# 4.6 |  1.16786 |  1.52070
#
# 4.8 |  1.18397 |  1.69846
#
# 5.0 |  1.19884 |  1.89490
#
# 5.2 |  1.21259 |  2.11202
#
# ...

# %%
#----------- h = 0.1 --------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])

    return (t,y)

def f(t,y):
    return (cos(y))**2

# solucao numerica
t,y = euler_expl (0, 10, 0, 0.1, f)
            
# solucao exata
yex = np.tan(y)**-1

# erro
erro = np.abs (y - yex)
plt.plot (erro, 'g', label = '$Erro Rel$')
plt.legend()

# limite de integração
lim_erro = 0.1*(0.5*np.exp(1)**2-2)*(np.exp(t)-1.)


#tabela
print ("Imprimindo comparação... \n\n ti |    ei   | Ei   \n")
for i in range(len(y)):
    print("{0:.1f} | {1: 0.5f} | {2: 0.5f} \n".format (t[i], erro[i], lim_erro[i]))
# Out:
# C:\Users\anaca\Anaconda3\envs\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: divide by zero encountered in reciprocal
# Imprimindo comparação...
#
#  ti |    ei   | Ei
#
# 0.0 |  inf |  0.00000
#
# 0.1 |  9.86664 |  0.01782
#
# 0.2 |  4.75953 |  0.03752
#
# 0.3 |  2.99470 |  0.05928
#
# 0.4 |  2.06959 |  0.08334
#
# 0.5 |  1.48448 |  0.10993
#
# 0.6 |  1.07308 |  0.13931
#
# 0.7 |  0.76402 |  0.17178
#
# 0.8 |  0.52136 |  0.20767
#
# 0.9 |  0.32484 |  0.24733
#
# 1.0 |  0.16201 |  0.29117
#
# 1.1 |  0.02471 |  0.33961
#
# 1.2 |  0.09269 |  0.39315
#
# 1.3 |  0.19425 |  0.45232
#
# 1.4 |  0.28295 |  0.51771
#
# 1.5 |  0.36108 |  0.58998
#
# 1.6 |  0.43041 |  0.66985
#
# 1.7 |  0.49232 |  0.75812
#
# 1.8 |  0.54794 |  0.85568
#
# 1.9 |  0.59816 |  0.96349
#
# 2.0 |  0.64373 |  1.08264
#
# 2.1 |  0.68525 |  1.21433
#
# 2.2 |  0.72324 |  1.35986
#
# 2.3 |  0.75813 |  1.52070
#
# 2.4 |  0.79027 |  1.69846
#
# 2.5 |  0.81998 |  1.89490
#
# 2.6 |  0.84751 |  2.11202
#
# ...

# %%
#----------- h = 0.05 --------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])

    return (t,y)

def f(t,y):
    return (cos(y))**2

# solucao numerica
t,y = euler_expl (0, 10, 0, 0.05, f)
            
# solucao exata
yex = np.tan(y)**-1

# erro
erro = np.abs (y - yex)
plt.plot (erro, 'g', label = '$Erro Rel$')
plt.legend()

# limite de integração
lim_erro = 0.1*(0.5*np.exp(1)**2-2)*(np.exp(t)-1.)


#tabela
print ("Imprimindo comparação... \n\n ti |    ei   | Ei   \n")
for i in range(len(y)):
    print("{0:.1f} | {1: 0.5f} | {2: 0.5f} \n".format (t[i], erro[i], lim_erro[i]))
# Out:
# C:\Users\anaca\Anaconda3\envs\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: divide by zero encountered in reciprocal
# Imprimindo comparação...
#
#  ti |    ei   | Ei
#
# 0.0 |  inf |  0.00000
#
# 0.1 |  19.93333 |  0.00869
#
# 0.1 |  9.87932 |  0.01782
#
# 0.2 |  6.49518 |  0.02742
#
# 0.2 |  4.77908 |  0.03752
#
# 0.2 |  3.73081 |  0.04813
#
# 0.3 |  3.01710 |  0.05928
#
# 0.4 |  2.49520 |  0.07101
#
# 0.4 |  2.09380 |  0.08334
#
# 0.5 |  1.77331 |  0.09630
#
# 0.5 |  1.50998 |  0.10993
#
# 0.6 |  1.28872 |  0.12425
#
# 0.6 |  1.09945 |  0.13931
#
# 0.7 |  0.93516 |  0.15514
#
# 0.7 |  0.79087 |  0.17178
#
# 0.8 |  0.66286 |  0.18928
#
# 0.8 |  0.54835 |  0.20767
#
# 0.9 |  0.44519 |  0.22701
#
# 0.9 |  0.35168 |  0.24733
#
# 1.0 |  0.26647 |  0.26870
#
# 1.0 |  0.18846 |  0.29117
#
# 1.1 |  0.11675 |  0.31478
#
# 1.1 |  0.05059 |  0.33961
#
# 1.2 |  0.01066 |  0.36571
#
# 1.2 |  0.06752 |  0.39315
#
# 1.2 |  0.12047 |  0.42200
#
# 1.3 |  0.16988 |  0.45232
#
# ...

# %% [markdown]
# ${\bf b)}$ ${y'(t)}$ ${=}$ ${\dfrac {1}{1 + t^{2}}2[y(t)]^{2},}$  ${0}$ ${\leq}$ ${t}$ ${\leq}$ ${10,}$ ${y(0)= 0;}$ ${y(t) =}$ ${\dfrac {t}{1 + t^{2}}}$

# %%
# ----------- h = 0.2 --------------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])

    return (t,y)

def f(t,y):
    return 1./(1+t**2)

# solucao numerica
t,y = euler_expl (0, 10, 0, 0.2, f)
            
# solucao exata
yex = t/(1+t**2)

# erro
erro = np.abs (y - yex)
plt.plot (erro, 'g', label = '$Erro Rel$')
plt.legend()

# limite de integração
lim_erro = 0.1*(0.5*np.exp(1)**2-2)*(np.exp(t)-1.)

#tabela
print ("Imprimindo comparação... \n\n ti |    ei    |    Ei\n")
for i in range(len(y)):
    print("{0:.1f} | {1: 0.5f} | {2: 0.5f}\n".format (t[i], erro[i], lim_erro[i]))
# Out:
# Imprimindo comparação...
#
#  ti |    ei    |    Ei
#
# 0.0 |  0.00000 |  0.00000
#
# 0.2 |  0.00769 |  0.03752
#
# 0.4 |  0.04748 |  0.08334
#
# 0.6 |  0.12355 |  0.13931
#
# 0.8 |  0.22398 |  0.20767
#
# 1.0 |  0.33373 |  0.29117
#
# 1.2 |  0.44193 |  0.39315
#
# 1.4 |  0.54273 |  0.51771
#
# 1.6 |  0.63383 |  0.66985
#
# 1.8 |  0.71492 |  0.85568
#
# 2.0 |  0.78662 |  1.08264
#
# 2.2 |  0.84990 |  1.35986
#
# 2.4 |  0.90583 |  1.69846
#
# 2.6 |  0.95540 |  2.11202
#
# 2.8 |  0.99948 |  2.61714
#
# 3.0 |  1.03885 |  3.23410
#
# 3.2 |  1.07415 |  3.98765
#
# 3.4 |  1.10594 |  4.90805
#
# 3.6 |  1.13468 |  6.03222
#
# 3.8 |  1.16078 |  7.40529
#
# 4.0 |  1.18455 |  9.08236
#
# 4.2 |  1.20629 |  11.13073
#
# 4.4 |  1.22623 |  13.63263
#
# 4.6 |  1.24458 |  16.68844
#
# 4.8 |  1.26152 |  20.42083
#
# 5.0 |  1.27720 |  24.97957
#
# 5.2 |  1.29175 |  30.54764
#
# 5.4 |  1.30529 |  37.34849
#
# 5.6 |  1.31791 |  45.65506
#
# 5.8 |  1.32971 |  55.80073
#
# 6.0 |  1.34075 |  68.19269
#
# ...

# %%
# ----------- h = 0.1 --------------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])

    return (t,y)

def f(t,y):
    return 1./(1+t**2)

# solucao numerica
t,y = euler_expl (0, 10, 0, 0.1, f)
            
# solucao exata
yex = t/(1+t**2)

# erro
erro = np.abs (y - yex)
plt.plot (erro, 'g', label = '$Erro Rel$')
plt.legend()

# limite de integração
lim_erro = 0.1*(0.5*np.exp(1)**2-2)*(np.exp(t)-1.)

#tabela
print ("Imprimindo comparação... \n\n ti |    ei    |    Ei\n")
for i in range(len(y)):
    print("{0:.1f} | {1: 0.5f} | {2: 0.5f}\n".format (t[i], erro[i], lim_erro[i]))
# Out:
# Imprimindo comparação...
#
#  ti |    ei    |    Ei
#
# 0.0 |  0.00000 |  0.00000
#
# 0.1 |  0.00099 |  0.01782
#
# 0.2 |  0.00670 |  0.03752
#
# 0.3 |  0.01993 |  0.05928
#
# 0.4 |  0.04208 |  0.08334
#
# 0.5 |  0.07311 |  0.10993
#
# 0.6 |  0.11194 |  0.13931
#
# 0.7 |  0.15684 |  0.17178
#
# 0.8 |  0.20595 |  0.20767
#
# 0.9 |  0.25750 |  0.24733
#
# 1.0 |  0.30998 |  0.29117
#
# 1.1 |  0.36224 |  0.33961
#
# 1.2 |  0.41343 |  0.39315
#
# 1.3 |  0.46294 |  0.45232
#
# 1.4 |  0.51042 |  0.51771
#
# 1.5 |  0.55563 |  0.58998
#
# 1.6 |  0.59850 |  0.66985
#
# 1.7 |  0.63901 |  0.75812
#
# 1.8 |  0.67721 |  0.85568
#
# 1.9 |  0.71318 |  0.96349
#
# 2.0 |  0.74702 |  1.08264
#
# 2.1 |  0.77885 |  1.21433
#
# 2.2 |  0.80879 |  1.35986
#
# 2.3 |  0.83696 |  1.52070
#
# 2.4 |  0.86349 |  1.69846
#
# 2.5 |  0.88849 |  1.89490
#
# 2.6 |  0.91206 |  2.11202
#
# 2.7 |  0.93430 |  2.35196
#
# 2.8 |  0.95531 |  2.61714
#
# 2.9 |  0.97519 |  2.91021
#
# 3.0 |  0.99400 |  3.23410
#
# ...

# %%
# ----------- h = 0.05 --------------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])

    return (t,y)

def f(t,y):
    return 1./(1+t**2)

# solucao numerica
t,y = euler_expl (0, 10, 0, 0.05, f)
            
# solucao exata
yex = t/(1+t**2)

# erro
erro = np.abs (y - yex)
plt.plot (erro, 'g', label = '$Erro Rel$')
plt.legend()

# limite de integração
lim_erro = 0.1*(0.5*np.exp(1)**2-2)*(np.exp(t)-1.)

#tabela
print ("Imprimindo comparação... \n\n ti |    ei    |    Ei\n")
for i in range(len(y)):
    print("{0:.1f} | {1: 0.5f} | {2: 0.5f}\n".format (t[i], erro[i], lim_erro[i]))
# Out:
# Imprimindo comparação...
#
#  ti |    ei    |    Ei
#
# 0.0 |  0.00000 |  0.00000
#
# 0.1 |  0.00012 |  0.00869
#
# 0.1 |  0.00087 |  0.01782
#
# 0.2 |  0.00268 |  0.02742
#
# 0.2 |  0.00597 |  0.03752
#
# 0.2 |  0.01106 |  0.04813
#
# 0.3 |  0.01819 |  0.05928
#
# 0.4 |  0.02748 |  0.07101
#
# 0.4 |  0.03900 |  0.08334
#
# 0.5 |  0.05271 |  0.09630
#
# 0.5 |  0.06851 |  0.10993
#
# 0.6 |  0.08625 |  0.12425
#
# 0.6 |  0.10573 |  0.13931
#
# 0.7 |  0.12672 |  0.15514
#
# 0.7 |  0.14902 |  0.17178
#
# 0.8 |  0.17237 |  0.18928
#
# 0.8 |  0.19657 |  0.20767
#
# 0.9 |  0.22139 |  0.22701
#
# 0.9 |  0.24665 |  0.24733
#
# 1.0 |  0.27217 |  0.26870
#
# 1.0 |  0.29779 |  0.29117
#
# 1.1 |  0.32339 |  0.31478
#
# 1.1 |  0.34884 |  0.33961
#
# 1.2 |  0.37404 |  0.36571
#
# 1.2 |  0.39892 |  0.39315
#
# 1.2 |  0.42342 |  0.42200
#
# 1.3 |  0.44746 |  0.45232
#
# 1.4 |  0.47102 |  0.48420
#
# 1.4 |  0.49406 |  0.51771
#
# 1.5 |  0.51656 |  0.55294
#
# 1.5 |  0.53850 |  0.58998
#
# ...

# %% [markdown]
# ${\bf c)}$ ${y' =}$ ${\dfrac {1}{4}y(t)}$ ${[1 - {\dfrac {1}{20}y(t)],}}$ ${0}$ ${\leq}$ ${t}$ ${\leq}$ ${20,}$ ${y(0)= 1;}$ ${y(t) =}$ ${\dfrac {20}{1 + 19{\epsilon}^{-t/4}}}$

# %%
# ------------ h = 0.2 --------------------

import numpy as np
import math
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])

    return (t,y)

def f(t,y):
    return 1/4*(y)*(1-1/20*y)

# solucao numerica
t,y = euler_expl (0, 20, 1, 0.2, f)
            
# solucao exata
yex =  20/(1+19*exp(-t/4))

# erro
erro = np.abs (y - yex)
plt.plot (erro, 'g', label = '$Erro Rel$')
plt.legend()

# limite de integração
lim_erro = 0.1*(0.5*np.exp(1)**2-2)*(np.exp(t)-1.)

#tabela
print ("Imprimindo comparação... \n\n ti |    ei    |    Ei\n")
for i in range(len(y)):
    print("{0:.1f} | {1: 0.5f} | {2: 0.5f}\n".format (t[i], erro[i], lim_erro[i]))
# Out:
# Imprimindo comparação...
#
#  ti |    ei    |    Ei
#
# 0.0 |  0.00000 |  0.00000
#
# 0.2 |  0.00108 |  0.03752
#
# 0.4 |  0.00226 |  0.08334
#
# 0.6 |  0.00353 |  0.13931
#
# 0.8 |  0.00490 |  0.20767
#
# 1.0 |  0.00638 |  0.29117
#
# 1.2 |  0.00797 |  0.39315
#
# 1.4 |  0.00967 |  0.51771
#
# 1.6 |  0.01150 |  0.66985
#
# 1.8 |  0.01345 |  0.85568
#
# 2.0 |  0.01553 |  1.08264
#
# 2.2 |  0.01774 |  1.35986
#
# 2.4 |  0.02010 |  1.69846
#
# 2.6 |  0.02259 |  2.11202
#
# 2.8 |  0.02523 |  2.61714
#
# 3.0 |  0.02802 |  3.23410
#
# 3.2 |  0.03096 |  3.98765
#
# 3.4 |  0.03406 |  4.90805
#
# 3.6 |  0.03731 |  6.03222
#
# 3.8 |  0.04073 |  7.40529
#
# 4.0 |  0.04430 |  9.08236
#
# 4.2 |  0.04803 |  11.13073
#
# 4.4 |  0.05193 |  13.63263
#
# 4.6 |  0.05598 |  16.68844
#
# 4.8 |  0.06018 |  20.42083
#
# 5.0 |  0.06454 |  24.97957
#
# 5.2 |  0.06905 |  30.54764
#
# 5.4 |  0.07370 |  37.34849
#
# 5.6 |  0.07849 |  45.65506
#
# 5.8 |  0.08340 |  55.80073
#
# 6.0 |  0.08844 |  68.19269
#
# ...

# %%
# -----------h = 0.1 --------------------

import numpy as np
import math
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])

    return (t,y)

def f(t,y):
    return 1/4*(y)*(1-1/20*y)

# solucao numerica
t,y = euler_expl (0, 20, 1, 0.1, f)
            
# solucao exata
yex =  20/(1+19*exp(-t/4))

# erro
erro = np.abs (y - yex)
plt.plot (erro, 'g', label = '$Erro Rel$')
plt.legend()

# limite de integração
lim_erro = 0.1*(0.5*np.exp(1)**2-2)*(np.exp(t)-1.)

#tabela
print ("Imprimindo comparação... \n\n ti |    ei    |    Ei\n")
for i in range(len(y)):
    print("{0:.1f} | {1: 0.5f} | {2: 0.5f}\n".format (t[i], erro[i], lim_erro[i]))
# Out:
# Imprimindo comparação...
#
#  ti |    ei    |    Ei
#
# 0.0 |  0.00000 |  0.00000
#
# 0.1 |  0.00027 |  0.01782
#
# 0.2 |  0.00055 |  0.03752
#
# 0.3 |  0.00084 |  0.05928
#
# 0.4 |  0.00115 |  0.08334
#
# 0.5 |  0.00146 |  0.10993
#
# 0.6 |  0.00179 |  0.13931
#
# 0.7 |  0.00213 |  0.17178
#
# 0.8 |  0.00249 |  0.20767
#
# 0.9 |  0.00286 |  0.24733
#
# 1.0 |  0.00324 |  0.29117
#
# 1.1 |  0.00363 |  0.33961
#
# 1.2 |  0.00405 |  0.39315
#
# 1.3 |  0.00447 |  0.45232
#
# 1.4 |  0.00491 |  0.51771
#
# 1.5 |  0.00537 |  0.58998
#
# 1.6 |  0.00584 |  0.66985
#
# 1.7 |  0.00633 |  0.75812
#
# 1.8 |  0.00683 |  0.85568
#
# 1.9 |  0.00735 |  0.96349
#
# 2.0 |  0.00789 |  1.08264
#
# 2.1 |  0.00844 |  1.21433
#
# 2.2 |  0.00901 |  1.35986
#
# 2.3 |  0.00960 |  1.52070
#
# 2.4 |  0.01021 |  1.69846
#
# 2.5 |  0.01083 |  1.89490
#
# 2.6 |  0.01147 |  2.11202
#
# 2.7 |  0.01213 |  2.35196
#
# 2.8 |  0.01281 |  2.61714
#
# 2.9 |  0.01351 |  2.91021
#
# 3.0 |  0.01423 |  3.23410
#
# ...

# %%
# ------------ h = 0.05 --------------------

import numpy as np
import math
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])

    return (t,y)

def f(t,y):
    return 1/4*(y)*(1-1/20*y)

# solucao numerica
t,y = euler_expl (0, 20, 1, 0.05, f)
            
# solucao exata
yex =  20/(1+19*exp(-t/4))

# erro
erro = np.abs (y - yex)
plt.plot (erro, 'g', label = '$Erro Rel$')
plt.legend()

# limite de integração
lim_erro = 0.1*(0.5*np.exp(1)**2-2)*(np.exp(t)-1.)

#tabela
print ("Imprimindo comparação... \n\n ti |    ei    |    Ei\n")
for i in range(len(y)):
    print("{0:.1f} | {1: 0.5f} | {2: 0.5f}\n".format (t[i], erro[i], lim_erro[i]))
# Out:
# Imprimindo comparação...
#
#  ti |    ei    |    Ei
#
# 0.0 |  0.00000 |  0.00000
#
# 0.1 |  0.00007 |  0.00869
#
# 0.1 |  0.00014 |  0.01782
#
# 0.2 |  0.00021 |  0.02742
#
# 0.2 |  0.00028 |  0.03752
#
# 0.2 |  0.00035 |  0.04813
#
# 0.3 |  0.00042 |  0.05928
#
# 0.4 |  0.00050 |  0.07101
#
# 0.4 |  0.00058 |  0.08334
#
# 0.5 |  0.00066 |  0.09630
#
# 0.5 |  0.00074 |  0.10993
#
# 0.6 |  0.00082 |  0.12425
#
# 0.6 |  0.00090 |  0.13931
#
# 0.7 |  0.00099 |  0.15514
#
# 0.7 |  0.00107 |  0.17178
#
# 0.8 |  0.00116 |  0.18928
#
# 0.8 |  0.00125 |  0.20767
#
# 0.9 |  0.00135 |  0.22701
#
# 0.9 |  0.00144 |  0.24733
#
# 1.0 |  0.00153 |  0.26870
#
# 1.0 |  0.00163 |  0.29117
#
# 1.1 |  0.00173 |  0.31478
#
# 1.1 |  0.00183 |  0.33961
#
# 1.2 |  0.00193 |  0.36571
#
# 1.2 |  0.00204 |  0.39315
#
# 1.2 |  0.00214 |  0.42200
#
# 1.3 |  0.00225 |  0.45232
#
# 1.4 |  0.00236 |  0.48420
#
# 1.4 |  0.00247 |  0.51771
#
# 1.5 |  0.00259 |  0.55294
#
# 1.5 |  0.00270 |  0.58998
#
# ...

# %% [markdown]
# ${\bf d)}$ ${y'(t) =}$ ${-[y(t)]^{2},}$ ${y(t) =}$ ${\dfrac {1}{t},}$ ${0}$ ${\leq}$ ${t}$ ${\leq}$ ${10,}$ ${y(1)= 1;}$ ${y(t) =}$ ${\dfrac {1}{t}}$

# %%
# ----------- h = 0.2 --------------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])

    return (t,y)

def f(t,y):
    return  -(y)**2

# solucao numerica
t,y = euler_expl (1, 10, 1, 0.2, f)
            
# solucao exata
yex =  1/t

# erro
erro = np.abs (y - yex)
plt.plot (erro, 'g', label = '$Erro Rel$')
plt.legend()

# limite de integração
lim_erro = 0.1*(0.5*np.exp(1)**2-2)*(np.exp(t)-1.)

#tabela
print ("Imprimindo comparação... \n\n ti |    ei    |    Ei\n")
for i in range(len(y)):
    print("{0:.1f} | {1: 0.5f} | {2: 0.5f}\n".format (t[i], erro[i], lim_erro[i]))
# Out:
# Imprimindo comparação...
#
#  ti |    ei    |    Ei
#
# 1.0 |  0.00000 |  0.29117
#
# 1.2 |  0.03333 |  0.39315
#
# 1.4 |  0.04229 |  0.51771
#
# 1.6 |  0.04332 |  0.66985
#
# 1.8 |  0.04154 |  0.85568
#
# 2.0 |  0.03883 |  1.08264
#
# 2.2 |  0.03591 |  1.35986
#
# 2.4 |  0.03308 |  1.69846
#
# 2.6 |  0.03046 |  2.11202
#
# 2.8 |  0.02807 |  2.61714
#
# 3.0 |  0.02592 |  3.23410
#
# 3.2 |  0.02399 |  3.98765
#
# 3.4 |  0.02225 |  4.90805
#
# 3.6 |  0.02069 |  6.03222
#
# 3.8 |  0.01929 |  7.40529
#
# 4.0 |  0.01803 |  9.08236
#
# 4.2 |  0.01689 |  11.13073
#
# 4.4 |  0.01585 |  13.63263
#
# 4.6 |  0.01491 |  16.68844
#
# 4.8 |  0.01405 |  20.42083
#
# 5.0 |  0.01327 |  24.97957
#
# 5.2 |  0.01255 |  30.54764
#
# 5.4 |  0.01189 |  37.34849
#
# 5.6 |  0.01128 |  45.65506
#
# 5.8 |  0.01072 |  55.80073
#
# 6.0 |  0.01020 |  68.19269
#
# 6.2 |  0.00972 |  83.32825
#
# 6.4 |  0.00928 |  101.81488
#
# 6.6 |  0.00886 |  124.39449
#
# 6.8 |  0.00848 |  151.97329
#
# ...

# %%
# ----------- h = 0.1 --------------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])

    return (t,y)

def f(t,y):
    return  -(y)**2

# solucao numerica
t,y = euler_expl (1, 10, 1, 0.1, f)
            
# solucao exata
yex =  1/t

# erro
erro = np.abs (y - yex)
plt.plot (erro, 'g', label = '$Erro Rel$')
plt.legend()

# limite de integração
lim_erro = 0.1*(0.5*np.exp(1)**2-2)*(np.exp(t)-1.)

#tabela
print ("Imprimindo comparação... \n\n ti |    ei    |    Ei\n")
for i in range(len(y)):
    print("{0:.1f} | {1: 0.5f} | {2: 0.5f}\n".format (t[i], erro[i], lim_erro[i]))
# Out:
# Imprimindo comparação...
#
#  ti |    ei    |    Ei
#
# 1.0 |  0.00000 |  0.29117
#
# 1.1 |  0.00909 |  0.33961
#
# 1.2 |  0.01433 |  0.39315
#
# 1.3 |  0.01731 |  0.45232
#
# 1.4 |  0.01890 |  0.51771
#
# 1.5 |  0.01964 |  0.58998
#
# 1.6 |  0.01984 |  0.66985
#
# 1.7 |  0.01969 |  0.75812
#
# 1.8 |  0.01934 |  0.85568
#
# 1.9 |  0.01885 |  0.96349
#
# 2.0 |  0.01829 |  1.08264
#
# 2.1 |  0.01768 |  1.21433
#
# 2.2 |  0.01706 |  1.35986
#
# 2.3 |  0.01644 |  1.52070
#
# 2.4 |  0.01582 |  1.69846
#
# 2.5 |  0.01522 |  1.89490
#
# 2.6 |  0.01464 |  2.11202
#
# 2.7 |  0.01409 |  2.35196
#
# 2.8 |  0.01355 |  2.61714
#
# 2.9 |  0.01304 |  2.91021
#
# 3.0 |  0.01256 |  3.23410
#
# 3.1 |  0.01209 |  3.59205
#
# 3.2 |  0.01165 |  3.98765
#
# 3.3 |  0.01123 |  4.42486
#
# 3.4 |  0.01084 |  4.90805
#
# 3.5 |  0.01046 |  5.44205
#
# 3.6 |  0.01010 |  6.03222
#
# 3.7 |  0.00976 |  6.68446
#
# 3.8 |  0.00943 |  7.40529
#
# 3.9 |  0.00912 |  8.20193
#
# 4.0 |  0.00883 |  9.08236
#
# ...

# %%
# ----------- h = 0.05 --------------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])

    return (t,y)

def f(t,y):
    return  -(y)**2

# solucao numerica
t,y = euler_expl (1, 10, 1, 0.05, f)
            
# solucao exata
yex =  1/t

# erro
erro = np.abs (y - yex)
plt.plot (erro, 'g', label = '$Erro Rel$')
plt.legend()

# limite de integração
lim_erro = 0.1*(0.5*np.exp(1)**2-2)*(np.exp(t)-1.)

#tabela
print ("Imprimindo comparação... \n\n ti |    ei    |    Ei\n")
for i in range(len(y)):
    print("{0:.1f} | {1: 0.5f} | {2: 0.5f}\n".format (t[i], erro[i], lim_erro[i]))
# Out:
# Imprimindo comparação...
#
#  ti |    ei    |    Ei
#
# 1.0 |  0.00000 |  0.29117
#
# 1.1 |  0.00238 |  0.31478
#
# 1.1 |  0.00422 |  0.33961
#
# 1.1 |  0.00563 |  0.36571
#
# 1.2 |  0.00672 |  0.39315
#
# 1.2 |  0.00755 |  0.42200
#
# 1.3 |  0.00818 |  0.45232
#
# 1.4 |  0.00865 |  0.48420
#
# 1.4 |  0.00899 |  0.51771
#
# 1.4 |  0.00923 |  0.55294
#
# 1.5 |  0.00939 |  0.58998
#
# 1.6 |  0.00949 |  0.62892
#
# 1.6 |  0.00953 |  0.66985
#
# 1.6 |  0.00953 |  0.71288
#
# 1.7 |  0.00950 |  0.75812
#
# 1.8 |  0.00944 |  0.80568
#
# 1.8 |  0.00936 |  0.85568
#
# 1.9 |  0.00926 |  0.90824
#
# 1.9 |  0.00915 |  0.96349
#
# 2.0 |  0.00903 |  1.02158
#
# 2.0 |  0.00890 |  1.08264
#
# 2.0 |  0.00876 |  1.14684
#
# 2.1 |  0.00862 |  1.21433
#
# 2.2 |  0.00848 |  1.28528
#
# 2.2 |  0.00833 |  1.35986
#
# 2.2 |  0.00819 |  1.43827
#
# 2.3 |  0.00804 |  1.52070
#
# 2.4 |  0.00789 |  1.60736
#
# 2.4 |  0.00775 |  1.69846
#
# 2.5 |  0.00761 |  1.79423
#
# 2.5 |  0.00747 |  1.89490
#
# ...

# %% [markdown]
# ${\bf Problema}$ ${\bf 2:}$ Considere o problema linear
#
# ${y'(t) = {\lambda}y(t) + (1 - {\lambda})cos(t) - (1 + {\lambda})sen(t),}$ ${y(0) = 1.}$
#
# A solução exata é ${y(t) = sen(t) + cos(t).}$ Resolva este problema usando o método de Euler com vários valores de ${\lambda}$ e ${h,}$ para ${0}$ ${\leq}$ ${t}$ ${\leq}$ ${10.}$ Comente sobre os resultados.
#
# ${\bf a)}$ ${\lambda = 1;}$ ${h = 0.5, 0.25, 0.125}$

# %%
# ----------- h = 0.5 --------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])
    return (t,y)

# define função
# 1*(y)+(1-1)cos(t)-(1+1)sin(t) = y-2cos(t)
f = lambda t,y: y-2*np.cos(t)

# chamando o metodo 'Solução Numérica'
t,y = euler_expl(0, 10, 1, 0.5, f)

# plotar funcoes
yex = np.sin(t)+np.cos(t)
plt.plot (t,y,'c--', label ='$y_h (t)$')
plt.plot (t,yex ,'g', label ='y(t)')
plt.legend ()

# %%
# ----------- h = 0.25 --------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])
    return (t,y)

# define função
# 1*(y)+(1-1)cos(t)-(1+1)sin(t) = y-2cos(t)
f = lambda t,y: y-2*np.cos(t)

# chamando o metodo 'Solução Numérica'
t,y = euler_expl(0, 10, 1, 0.25, f)

# plotar funcoes
yex = np.sin(t)+np.cos(t)
plt.plot (t,y,'c--', label ='$y_h (t)$')
plt.plot (t,yex ,'g', label ='y(t)')
plt.legend ()

# %%
# ----------- h = 0.125 --------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])
    return (t,y)

# define função
# 1*(y)+(1-1)cos(t)-(1+1)sin(t) = y-2cos(t)
f = lambda t,y: y-2*np.cos(t)

# chamando o metodo 'Solução Numérica'
t,y = euler_expl(0, 10, 1, 0.125, f)

# plotar funcoes
yex = np.sin(t)+np.cos(t)
plt.plot (t,y,'c--', label ='$y_h (t)$')
plt.plot (t,yex ,'g', label ='y(t)')
plt.legend ()

# %% [markdown]
# ${\bf b)}$ Valores iguais ao item ${\bf a)}$

# %% [markdown]
# ${\bf c)}$ ${\lambda = 5;}$ ${h = 0.5, 0.25, 0.125,0.0625}$

# %%
# ----------- h = 0.5 --------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])
    return (t,y)

# define função
#def f(t,y):
#    return 5*(y)-4*(np.cos(t))-6*(sin(t))

# 5*(y)+(1-5)cos(t)-(1+5)sin(t) = 5y-4cos(t)-6sin(t)
f = lambda t,y: 5*(y)-4*np.cos(t)-6*sin(t)

# Solução Numérica
t,y = euler_expl(0, 10, 1, 0.5, f)

# solução exata
yex = np.sin(t) + np.cos(t)

# plota funções
plt.plot (t, y, 'c--', label ='$y_h (t)$')
plt.plot (t, yex, 'g', label ='y(t)')
plt.legend ()

# %%
# ----------- h = 0.25 --------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])
    return (t,y)

# define função
#def f(t,y):
#    return 5*(y)-4*(np.cos(t))-6*(sin(t))

# 5*(y)+(1-5)cos(t)-(1+5)sin(t) = 5y-4cos(t)-6sin(t)
f = lambda t,y: 5*(y)-4*np.cos(t)-6*sin(t)

# Solução Numérica
t,y = euler_expl(0, 10, 1, 0.25, f)

# solução exata
yex = np.sin(t) + np.cos(t)

# plota funções
plt.plot (t, y, 'c--', label ='$y_h (t)$')
plt.plot (t, yex, 'g', label ='y(t)')
plt.legend ()

# %%
# ----------- h = 0.125 --------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])
    return (t,y)

# define função
#def f(t,y):
#    return 5*(y)-4*(np.cos(t))-6*(sin(t))

# 5*(y)+(1-5)cos(t)-(1+5)sin(t) = 5y-4cos(t)-6sin(t)
f = lambda t,y: 5*(y)-4*np.cos(t)-6*sin(t)

# Solução Numérica
t,y = euler_expl(0, 10, 1, 0.125, f)

# solução exata
yex = np.sin(t) + np.cos(t)

# plota funções
plt.plot (t, y, 'c--', label ='$y_h (t)$')
plt.plot (t, yex, 'g', label ='y(t)')
plt.legend ()

# %%
# ----------- h = 0.0625 --------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])
    return (t,y)

# define função
#def f(t,y):
#    return 5*(y)-4*(np.cos(t))-6*(sin(t))

# 5*(y)+(1-5)cos(t)-(1+5)sin(t) = 5y-4cos(t)-6sin(t)
f = lambda t,y: 5*(y)-4*np.cos(t)-6*sin(t)

# Solução Numérica
t,y = euler_expl(0, 10, 1, 0.0625, f)

# solução exata
yex = np.sin(t) + np.cos(t)

# plota funções
plt.plot (t, y, 'c--', label ='$y_h (t)$')
plt.plot (t, yex, 'g', label ='y(t)')
plt.legend ()

# %% [markdown]
# ${\bf d)}$ ${\lambda = 5;}$ ${h = 0.125,0.0625}$
#
# ${\bf OBS:}$ Nessa letra ${\bf d)}$ os gráficos são iguais aos dois últimos do item anterior.

# %% [markdown]
# ${\bf Problema}$ ${\bf 3:}$ Faça  uma análise do erro obtido pelo método de Euler ao se resolver o caso ${\bf a)}$ do problema 2, ${h = 0.25.}$

# %%
# ----------- h = 0.25, lambda = 1 --------------

import numpy as np
import matplotlib.pyplot as plt
from numpy import *

def euler_expl (t0, tf, y0, h, fun):
    n = round (( tf - t0)/h + 1)
    t = linspace (t0, t0 +(n-1)*h, n)
    y = linspace (t0, t0 +(n-1)*h, n)
    y = zeros ((n ,))

    y[0] = y0

    for i in range (1,n):
        y[i] = y[i-1] + h*f(t[i-1], y[i-1])
    return (t,y)

# define função
# 1*(y)+(1-1)cos(t)-(1+1)sin(t) = y-2cos(t)
f = lambda t,y: y-2*(np.cos(t))

# chamando o metodo 'Solução Numérica'
t,y = euler_expl(0, 10, 1, 0.25, f)

# Sol exata
yex = np.sin(t)+np.cos(t)

# erro
erro = np.abs (y - yex)
plt.plot (erro, 'm', label = '$Erro Rel$')
plt.legend()

# limite de integração
#lim_erro = 0.1*(0.5*np.exp(1)**2-2)*(np.exp(t)-1.)

# plota funções
plt.plot (t,y,'c--', label ='$y_h (t)$')
plt.plot (t,yex ,'g', label ='y(t)')
plt.legend ()

#tabela
print ("Imprimindo comparação... \n\n ti |    ei    |    Ei\n")
for i in range(len(y)):
    print("{0:.1f} | {1: 0.5f} | {2: 0.5f}\n".format (t[i], erro[i], lim_erro[i]))
# Out:
# Imprimindo comparação...
#
#  ti |    ei    |    Ei
#
# 0.0 |  0.00000 |  0.29117
#
# 0.2 |  0.46632 |  0.31478
#
# 0.5 |  0.90396 |  0.33961
#
# 0.8 |  1.28581 |  0.36571
#
# 1.0 |  1.58823 |  0.39315
#
# 1.2 |  1.79252 |  0.42200
#
# 1.5 |  1.88616 |  0.45232
#
# 1.8 |  1.86352 |  0.48420
#
# 2.0 |  1.72626 |  0.51771
#
# 2.2 |  1.48321 |  0.55294
#
# 2.5 |  1.14988 |  0.58998
#
# 2.8 |  0.74748 |  0.62892
#
# 3.0 |  0.30162 |  0.66985
#
# 3.2 |  0.15920 |  0.71288
#
# 3.5 |  0.60540 |  0.75812
#
# 3.8 |  1.00805 |  0.80568
#
# 4.0 |  1.34064 |  0.85568
#
# 4.2 |  1.58064 |  0.90824
#
# 4.5 |  1.71082 |  0.96349
#
# 4.8 |  1.72021 |  1.02158
#
# 5.0 |  1.60461 |  1.08264
#
# 5.2 |  1.36670 |  1.14684
#
# 5.5 |  1.01564 |  1.21433
#
# 5.8 |  0.56622 |  1.28528
#
# 6.0 |  0.03756 |  1.35986
#
# 6.2 |  0.54846 |  1.43827
#
# 6.5 |  1.16917 |  1.52070
#
# 6.8 |  1.80317 |  1.60736
#
# 7.0 |  2.43254 |  1.69846
#
# 7.2 |  3.04502 |  1.79423
#
# 7.5 |  3.63611 |  1.89490
#
# ...
